# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers &>/dev/null
# !pip install tokenizers &>/dev/null

# %%
# %cd /content/drive/MyDrive/EdgeML_Team/Bert-Entity-Extraction using TensorFlow/src
# Out:
# /content/drive/.shortcut-targets-by-id/1V00Rw4heDRzQ510ETejMJzZTafbGihWs/EdgeML_Team/Bert-Entity-Extraction using TensorFlow/src

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
import tensorflow as tf
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# !TF_CPP_MIN_LOG_LEVEL=2 python train.py
# Out:
# =======================================1=======================================
# =======================================2=======================================
# =======================================3=======================================
# 2021-05-19 09:43:40.919790: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# INFO:absl:Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# Some layers from the model checkpoint at /content/drive/MyDrive/BERT/input/bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at /content/drive/MyDrive/BERT/input/bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 400)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 400)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 400)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_1[0][0]
#                                                                  input_3[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 400, 768)     0           tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 400, 18)      13842       dropout_37[0][0]
# ==================================================================================================
# Total params: 109,496,082
# Trainable params: 109,496,082
# Non-trainable params: 0
# __________________________________________________________________________________________________
# =======================================4=======================================
# =======================================5=======================================
# Epoch 1/10
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 704/704 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9422WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 704/704 [==============================] - 280s 292ms/step - loss: 0.1244 - accuracy: 0.9423 - val_loss: 7.1652e-06 - val_accuracy: 0.9701
# Epoch 2/10
# 704/704 [==============================] - 147s 209ms/step - loss: 6.1683e-05 - accuracy: 0.9706 - val_loss: 2.5615e-06 - val_accuracy: 0.9701
# Epoch 3/10
# 704/704 [==============================] - 147s 209ms/step - loss: 3.5799e-05 - accuracy: 0.9705 - val_loss: 9.3151e-07 - val_accuracy: 0.9701
# Epoch 4/10
# 704/704 [==============================] - 148s 210ms/step - loss: 1.8933e-05 - accuracy: 0.9705 - val_loss: 4.9790e-07 - val_accuracy: 0.9701
# Epoch 5/10
# 704/704 [==============================] - 147s 209ms/step - loss: 8.6627e-06 - accuracy: 0.9705 - val_loss: 3.5816e-07 - val_accuracy: 0.9701
# Epoch 6/10
# 704/704 [==============================] - 147s 209ms/step - loss: 1.9216e-05 - accuracy: 0.9704 - val_loss: 3.3331e-07 - val_accuracy: 0.9701
# Epoch 7/10
# 704/704 [==============================] - 147s 209ms/step - loss: 3.9489e-05 - accuracy: 0.9705 - val_loss: 3.0822e-07 - val_accuracy: 0.9701
# Epoch 8/10
# 704/704 [==============================] - 147s 209ms/step - loss: 1.8358e-05 - accuracy: 0.9705 - val_loss: 2.2253e-07 - val_accuracy: 0.9701
# Epoch 9/10
# 704/704 [==============================] - 147s 209ms/step - loss: 7.9091e-05 - accuracy: 0.9705 - val_loss: 2.0054e-07 - val_accuracy: 0.9701
# Epoch 10/10
# 704/704 [==============================] - 147s 209ms/step - loss: 8.2766e-06 - accuracy: 0.9704 - val_loss: 9.2654e-08 - val_accuracy: 0.9701
# 1
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python predict.py
# Out:
# 2021-05-20 12:27:22.374877: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Some layers from the model checkpoint at /content/drive/MyDrive/BERT/input/bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at /content/drive/MyDrive/BERT/input/bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# B-ACCOUNT # --> 72645
# B-ADMIT DATE --> 06 / 21 / 201
# B-ADMITTING DIAGNOSIS --> breast breast
# B-ADMITTING PHYSICIAN --> courtney
# B-AGE --> 75
# B-BIRTH DATE --> 03 / 21 / 19
# B-MR NUMBER --> 990652395980
# B-PATIENT NAME --> roberts
# roberts
# B-PATIENT PHONE # --> 473 23894034
# B-PRIMARY INSURANCE PLAN --> pacific
# pacific
# B-SOCIAL SECURITY # --> 864
# I-ADMITTING DIAGNOSIS --> disease disease
# I-ADMITTING PHYSICIAN --> patterson
# I-PATIENT NAME -->
# I-PRIMARY INSURANCE PLAN -->
#
# I-SOCIAL SECURITY # --> - 37 - 5912 - 457 - 7850
# O -->
# {'Account_no': ['72645'], 'Admit_Date': ['06 / 21 / 201'], 'MR_Number': ['99065239'], 'Patient_Name': ['roberts '], 'Social_Security_no': ['864375912'], 'Age': ['75'], 'DOB': ['03 / 21 / 19'], 'Patient_Phone_no': ['4732389403'], 'Admitting_Disease': ['breast disease'], 'Admitting_Physician': ['courtney patterson'], 'Primary_Insurance_Policy': ['pacific care']}
# B-ACCOUNT # --> 02487
# B-ADMIT DATE --> 02 / 24 / 202
# B-ADMITTING DIAGNOSIS --> prostate prostate
# B-ADMITTING PHYSICIAN --> christopher
# B-AGE --> 20
# B-BIRTH DATE --> 01 / 07 / 201 / ky
# B-MR NUMBER --> 54391500
# B-PATIENT NAME --> robertson
# robertson
# B-PATIENT PHONE # --> 42 446 9017 334830940
# B-PRIMARY INSURANCE PLAN --> northern
# northern
# B-SOCIAL SECURITY # --> 066
# I-ADMITTING DIAGNOSIS --> disease disease
# I-ADMITTING PHYSICIAN --> johnson
# I-PATIENT NAME --> jeffrey
# I-PRIMARY INSURANCE PLAN -->
#
# I-SOCIAL SECURITY # --> - 58 - 6681 952
# O -->
# {'Account_no': ['72645', '02487'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202'], 'MR_Number': ['99065239', '54391500'], 'Patient_Name': ['roberts ', 'robertson jeffrey'], 'Social_Security_no': ['864375912', '066586681'], 'Age': ['75', '20'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky'], 'Patient_Phone_no': ['4732389403', '4244690173'], 'Admitting_Disease': ['breast disease', 'prostate disease'], 'Admitting_Physician': ['courtney patterson', 'christopher johnson'], 'Primary_Insurance_Policy': ['pacific care', 'northern care']}
# B-ACCOUNT # --> 68907
# B-ADMIT DATE --> 09 / 14 / 201
# B-ADMITTING DIAGNOSIS --> retinalchemia retinalchemia
# B-ADMITTING PHYSICIAN --> monica
# B-AGE --> 92
# B-BIRTH DATE --> 09 / 07 / 19
# B-MR NUMBER --> 39954861
# B-PATIENT NAME --> kidd
# kidd
# B-PATIENT PHONE # -->
# B-PRIMARY INSURANCE PLAN --> western
# western
# B-SOCIAL SECURITY # --> 439
# I-ADMITTING DIAGNOSIS --> is is
# I-ADMITTING PHYSICIAN --> miller
# I-PATIENT NAME --> brandi
# I-PRIMARY INSURANCE PLAN -->
#
# I-SOCIAL SECURITY # --> - 96 - 8298
# O -->
# {'Account_no': ['72645', '02487', '68907'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201'], 'MR_Number': ['99065239', '54391500', '39954861'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi'], 'Social_Security_no': ['864375912', '066586681', '439968298'], 'Age': ['75', '20', '92'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19'], 'Patient_Phone_no': ['4732389403', '4244690173', ''], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is'], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care']}
# B-ACCOUNT # --> 99784
# B-ADMIT DATE --> 10 / 28 / 201
# B-ADMITTING DIAGNOSIS --> herpes herpes
# B-ADMITTING PHYSICIAN --> carol
# B-AGE --> 85
# B-BIRTH DATE --> 10 / 08 / 19
# B-MR NUMBER --> 43968308
# B-PATIENT NAME --> moore
# moore
# B-PATIENT PHONE # --> 60814 677
# B-PRIMARY INSURANCE PLAN --> northern
# northern
# B-SOCIAL SECURITY # --> 049
# I-ADMITTING DIAGNOSIS --> simplex simplex
# I-ADMITTING PHYSICIAN --> christopher roth
# I-PATIENT NAME --> jason
# I-PRIMARY INSURANCE PLAN --> care
# care
# I-SOCIAL SECURITY # --> - 58 - 0467 - 280 - 2231
# O -->
# {'Account_no': ['72645', '02487', '68907', '99784'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201', '10 / 28 / 201'], 'MR_Number': ['99065239', '54391500', '39954861', '43968308'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi', 'moore jason'], 'Social_Security_no': ['864375912', '066586681', '439968298', '049580467'], 'Age': ['75', '20', '92', '85'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19', '10 / 08 / 19'], 'Patient_Phone_no': ['4732389403', '4244690173', '', '60814677'], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is', 'herpes simplex'], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller', 'carol christopher'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care', 'northern care']}
# B-ACCOUNT # --> 97824
# B-ADMIT DATE --> 10 / 15 / 201
# B-ADMITTING DIAGNOSIS --> cancer cancer
# B-ADMITTING PHYSICIAN --> combs
# B-AGE --> 55
# B-BIRTH DATE --> 03 / 13 / 191
# B-MR NUMBER --> 72580097
# B-PATIENT NAME --> jones
# jones
# B-PATIENT PHONE # --> 4598473930
# B-PRIMARY INSURANCE PLAN --> western
# western
# B-SOCIAL SECURITY # --> 249
# I-ADMITTING DIAGNOSIS -->
# I-ADMITTING PHYSICIAN --> wendy hampton
# I-PATIENT NAME --> danielle
# I-PRIMARY INSURANCE PLAN --> care
# care
# I-SOCIAL SECURITY # --> - 40 - 5537
# O -->
# {'Account_no': ['72645', '02487', '68907', '99784', '97824'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201', '10 / 28 / 201', '10 / 15 / 201'], 'MR_Number': ['99065239', '54391500', '39954861', '43968308', '72580097'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi', 'moore jason', 'jones danielle'], 'Social_Security_no': ['864375912', '066586681', '439968298', '049580467', '249405537'], 'Age': ['75', '20', '92', '85', '55'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19', '10 / 08 / 19', '03 / 13 / 191'], 'Patient_Phone_no': ['4732389403', '4244690173', '', '60814677', '4598473930'], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is', 'herpes simplex', 'cancer '], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller', 'carol christopher', 'combs wendy'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care', 'northern care', 'western care']}
# B-ACCOUNT # --> 89410
# B-ADMIT DATE --> 12 / 07 / 201
# B-ADMITTING DIAGNOSIS --> alopecia alopecia
# B-ADMITTING PHYSICIAN --> jimmy
# B-AGE --> 58
# B-BIRTH DATE --> 09 / 11 / 191
# B-MR NUMBER --> 66103393
# B-PATIENT NAME --> davidson
# davidson
# B-PATIENT PHONE # --> 81 281
# B-PRIMARY INSURANCE PLAN -->
#
# B-SOCIAL SECURITY # --> 106
# I-ADMITTING DIAGNOSIS --> areata areata
# I-ADMITTING PHYSICIAN --> small
# I-PATIENT NAME --> yolanda jennifer
# I-PRIMARY INSURANCE PLAN -->
#
# I-SOCIAL SECURITY # --> - 87 - 1289
# O -->
# {'Account_no': ['72645', '02487', '68907', '99784', '97824', '89410'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201', '10 / 28 / 201', '10 / 15 / 201', '12 / 07 / 201'], 'MR_Number': ['99065239', '54391500', '39954861', '43968308', '72580097', '66103393'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi', 'moore jason', 'jones danielle', 'davidson yolanda jennifer'], 'Social_Security_no': ['864375912', '066586681', '439968298', '049580467', '249405537', '106871289'], 'Age': ['75', '20', '92', '85', '55', '58'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19', '10 / 08 / 19', '03 / 13 / 191', '09 / 11 / 191'], 'Patient_Phone_no': ['4732389403', '4244690173', '', '60814677', '4598473930', '81281'], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is', 'herpes simplex', 'cancer ', 'alopecia areata'], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller', 'carol christopher', 'combs wendy', 'jimmy small'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care', 'northern care', 'western care', '-']}
# B-ACCOUNT # --> 03880
# B-ADMIT DATE --> 04 / 29 / 202
# B-ADMITTING DIAGNOSIS --> gingivitis gingivitis
# B-ADMITTING PHYSICIAN --> bradley
# B-AGE --> 57
# B-BIRTH DATE --> 06 / 19 / 191
# B-MR NUMBER --> 28611094 55903601
# B-PATIENT NAME --> reeves
# reeves
# B-PATIENT PHONE # --> 06
# B-PRIMARY INSURANCE PLAN --> southern
# southern
# B-SOCIAL SECURITY # --> 275
# I-ADMITTING DIAGNOSIS -->
# I-ADMITTING PHYSICIAN --> mcdowell
# I-PATIENT NAME --> brian
# I-PRIMARY INSURANCE PLAN --> care
# care
# I-SOCIAL SECURITY # --> - 38 - 94926 - 414 - 4313
# O -->
# {'Account_no': ['72645', '02487', '68907', '99784', '97824', '89410', '03880'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201', '10 / 28 / 201', '10 / 15 / 201', '12 / 07 / 201', '04 / 29 / 202'], 'MR_Number': ['99065239', '54391500', '39954861', '43968308', '72580097', '66103393', '28611094'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi', 'moore jason', 'jones danielle', 'davidson yolanda jennifer', 'reeves brian'], 'Social_Security_no': ['864375912', '066586681', '439968298', '049580467', '249405537', '106871289', '275389492'], 'Age': ['75', '20', '92', '85', '55', '58', '57'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19', '10 / 08 / 19', '03 / 13 / 191', '09 / 11 / 191', '06 / 19 / 191'], 'Patient_Phone_no': ['4732389403', '4244690173', '', '60814677', '4598473930', '81281', '06'], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is', 'herpes simplex', 'cancer ', 'alopecia areata', 'gingivitis '], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller', 'carol christopher', 'combs wendy', 'jimmy small', 'bradley mcdowell'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care', 'northern care', 'western care', '-', 'southern care']}
# B-ACCOUNT # --> 84704
# B-ADMIT DATE --> 03 / 14 / 201
# B-ADMITTING DIAGNOSIS --> leukemia leukemia
# B-ADMITTING PHYSICIAN --> douglas
# B-AGE -->
# B-BIRTH DATE --> 11 / 25 / 20
# B-MR NUMBER --> 77879406
# B-PATIENT NAME --> brown carter
# brown carter
# B-PATIENT PHONE # --> 9991943 3249
# B-PRIMARY INSURANCE PLAN --> eastern
# eastern
# B-SOCIAL SECURITY # --> 350
# I-ADMITTING DIAGNOSIS --> surgery
# I-ADMITTING PHYSICIAN --> estrada
# I-PATIENT NAME --> stephanie
# I-PRIMARY INSURANCE PLAN -->
#
# I-SOCIAL SECURITY # --> - 77 - 5915 -
# O -->
# {'Account_no': ['72645', '02487', '68907', '99784', '97824', '89410', '03880', '84704'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201', '10 / 28 / 201', '10 / 15 / 201', '12 / 07 / 201', '04 / 29 / 202', '03 / 14 / 201'], 'MR_Number': ['99065239', '54391500', '39954861', '43968308', '72580097', '66103393', '28611094', '77879406'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi', 'moore jason', 'jones danielle', 'davidson yolanda jennifer', 'reeves brian', 'brown stephanie'], 'Social_Security_no': ['864375912', '066586681', '439968298', '049580467', '249405537', '106871289', '275389492', '350775915'], 'Age': ['75', '20', '92', '85', '55', '58', '57', ''], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19', '10 / 08 / 19', '03 / 13 / 191', '09 / 11 / 191', '06 / 19 / 191', '11 / 25 / 20'], 'Patient_Phone_no': ['4732389403', '4244690173', '', '60814677', '4598473930', '81281', '06', '9991943324'], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is', 'herpes simplex', 'cancer ', 'alopecia areata', 'gingivitis ', 'leukemia surgery'], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller', 'carol christopher', 'combs wendy', 'jimmy small', 'bradley mcdowell', 'douglas estrada'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care', 'northern care', 'western care', '-', 'southern care', 'eastern care']}
# B-ACCOUNT # --> 41203
# B-ADMIT DATE --> 10 / 02 / 201
# B-ADMITTING DIAGNOSIS --> atherosclerosis atherosclerosis
# B-ADMITTING PHYSICIAN --> phillip
# B-AGE --> 96
# B-BIRTH DATE --> 02 / 07 / 19
# B-MR NUMBER --> 78422297
# B-PATIENT NAME --> smith
# smith
# B-PATIENT PHONE # --> 001
# B-PRIMARY INSURANCE PLAN -->
#
# B-SOCIAL SECURITY # --> 857
# I-ADMITTING DIAGNOSIS -->
# I-ADMITTING PHYSICIAN --> garcia oliver
# I-PATIENT NAME --> brittany
# I-PRIMARY INSURANCE PLAN -->
#
# I-SOCIAL SECURITY # --> - 25 - 0757 - 590 - 251 -
# O -->
# {'Account_no': ['72645', '02487', '68907', '99784', '97824', '89410', '03880', '84704', '41203'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201', '10 / 28 / 201', '10 / 15 / 201', '12 / 07 / 201', '04 / 29 / 202', '03 / 14 / 201', '10 / 02 / 201'], 'MR_Number': ['99065239', '54391500', '39954861', '43968308', '72580097', '66103393', '28611094', '77879406', '78422297'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi', 'moore jason', 'jones danielle', 'davidson yolanda jennifer', 'reeves brian', 'brown stephanie', 'smith brittany'], 'Social_Security_no': ['864375912', '066586681', '439968298', '049580467', '249405537', '106871289', '275389492', '350775915', '857250757'], 'Age': ['75', '20', '92', '85', '55', '58', '57', '', '96'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19', '10 / 08 / 19', '03 / 13 / 191', '09 / 11 / 191', '06 / 19 / 191', '11 / 25 / 20', '02 / 07 / 19'], 'Patient_Phone_no': ['4732389403', '4244690173', '', '60814677', '4598473930', '81281', '06', '9991943324', '001'], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is', 'herpes simplex', 'cancer ', 'alopecia areata', 'gingivitis ', 'leukemia surgery', 'atherosclerosis '], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller', 'carol christopher', 'combs wendy', 'jimmy small', 'bradley mcdowell', 'douglas estrada', 'phillip garcia'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care', 'northern care', 'western care', '-', 'southern care', 'eastern care', '-']}
# B-ACCOUNT # --> 61138
# B-ADMIT DATE --> 02 / 17 / 202
# B-ADMITTING DIAGNOSIS --> asthma asthma
# B-ADMITTING PHYSICIAN --> jonathan
# B-AGE --> 70
# B-BIRTH DATE --> 07 / 21 / 19
# B-MR NUMBER --> 74010653
# B-PATIENT NAME --> mills
# mills
# B-PATIENT PHONE # -->
# B-PRIMARY INSURANCE PLAN --> northern
# northern
# B-SOCIAL SECURITY # --> 555 83
# I-ADMITTING DIAGNOSIS -->
# I-ADMITTING PHYSICIAN --> parker kelly
# I-PATIENT NAME --> pi
# I-PRIMARY INSURANCE PLAN -->
#
# I-SOCIAL SECURITY # --> - 18 - 3400 - 85
# O -->
# {'Account_no': ['72645', '02487', '68907', '99784', '97824', '89410', '03880', '84704', '41203', '61138'], 'Admit_Date': ['06 / 21 / 201', '02 / 24 / 202', '09 / 14 / 201', '10 / 28 / 201', '10 / 15 / 201', '12 / 07 / 201', '04 / 29 / 202', '03 / 14 / 201', '10 / 02 / 201', '02 / 17 / 202'], 'MR_Number': ['99065239', '54391500', '39954861', '43968308', '72580097', '66103393', '28611094', '77879406', '78422297', '74010653'], 'Patient_Name': ['roberts ', 'robertson jeffrey', 'kidd brandi', 'moore jason', 'jones danielle', 'davidson yolanda jennifer', 'reeves brian', 'brown stephanie', 'smith brittany', 'mills pi'], 'Social_Security_no': ['864375912', '066586681', '439968298', '049580467', '249405537', '106871289', '275389492', '350775915', '857250757', '555831834'], 'Age': ['75', '20', '92', '85', '55', '58', '57', '', '96', '70'], 'DOB': ['03 / 21 / 19', '01 / 07 / 201 / ky', '09 / 07 / 19', '10 / 08 / 19', '03 / 13 / 191', '09 / 11 / 191', '06 / 19 / 191', '11 / 25 / 20', '02 / 07 / 19', '07 / 21 / 19'], 'Patient_Phone_no': ['4732389403', '4244690173', '', '60814677', '4598473930', '81281', '06', '9991943324', '001', ''], 'Admitting_Disease': ['breast disease', 'prostate disease', 'retinalchemia is', 'herpes simplex', 'cancer ', 'alopecia areata', 'gingivitis ', 'leukemia surgery', 'atherosclerosis ', 'asthma '], 'Admitting_Physician': ['courtney patterson', 'christopher johnson', 'monica miller', 'carol christopher', 'combs wendy', 'jimmy small', 'bradley mcdowell', 'douglas estrada', 'phillip garcia', 'jonathan parker'], 'Primary_Insurance_Policy': ['pacific care', 'northern care', 'western care', 'northern care', 'western care', '-', 'southern care', 'eastern care', '-', 'northern care']}
#   Account_no  ... Primary_Insurance_Policy
# 0      72645  ...             pacific care
# 1      02487  ...            northern care
# 2      68907  ...             western care
# 3      99784  ...            northern care
# 4      97824  ...             western care
# 5      89410  ...                        -
# 6      03880  ...            southern care
# 7      84704  ...             eastern care
# 8      41203  ...                        -
# 9      61138  ...            northern care
#
# [10 rows x 11 columns]

# %%
# !pip install datasets
from datasets import load_dataset
dataset = load_dataset("conll2003")
dataset
# Out:
# Collecting datasets
#   Downloading https://files.pythonhosted.org/packages/46/1a/b9f9b3bfef624686ae81c070f0a6bb635047b17cdb3698c7ad01281e6f9a/datasets-1.6.2-py3-none-any.whl (221kB)
#      |████████████████████████████████| 225kB 13.3MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (20.9)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.11.1)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.41.1)
# Requirement already satisfied: pyarrow>=1.0.0<4.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Collecting fsspec
#   Downloading https://files.pythonhosted.org/packages/bc/52/816d1a3a599176057bf29dfacb1f8fadb61d35fbd96cb1bab4aaa7df83c0/fsspec-2021.5.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 24.6MB/s
# Collecting huggingface-hub<0.1.0
#   Downloading https://files.pythonhosted.org/packages/32/a1/7c5261396da23ec364e296a4fb8a1cd6a5a2ff457215c6447038f18c0309/huggingface_hub-0.0.9-py3-none-any.whl
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from datasets) (4.0.1)
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 21.2MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets) (3.7.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->datasets) (3.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: fsspec, huggingface-hub, xxhash, datasets
# Successfully installed datasets-1.6.2 fsspec-2021.5.0 huggingface-hub-0.0.9 xxhash-2.0.2
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=2603.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1781.0, style=ProgressStyle(description…
# Downloading and preparing dataset conll2003/conll2003 (download: 4.63 MiB, generated: 9.78 MiB, post-processed: Unknown size, total: 14.41 MiB) to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/40e7cb6bcc374f7c349c83acd1e9352a4f09474eb691f64f364ee62eb65d0ca6...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=649539.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=162714.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=145897.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset conll2003 downloaded and prepared to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/40e7cb6bcc374f7c349c83acd1e9352a4f09474eb691f64f364ee62eb65d0ca6. Subsequent calls will reuse this data.
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 14041
# })
